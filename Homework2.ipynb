# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Q1-Read the data https://raw.githubusercontent.com/ogut77/DataScience/main/data/Credit.csv

# %%
#Q2- Get data information and number of rows and columns
df = pd.read_csv('https://raw.githubusercontent.com/ogut77/DataScience/main/data/Credit.csv')
print(df.info())
print(df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Income     400 non-null    float64
#  1   Limit      400 non-null    int64
#  2   Rating     400 non-null    int64
#  3   Cards      400 non-null    int64
#  4   Age        400 non-null    int64
#  5   Education  400 non-null    int64
#  6   Own        400 non-null    object
#  7   Student    400 non-null    object
#  8   Married    400 non-null    object
#  9   Region     400 non-null    object
#  10  Balance    400 non-null    int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 34.5+ KB
# None
# (400, 11)

# %%
#Q3-Get first 3 rows of data
print(df.head(3))
# Out:
#     Income  Limit  Rating  Cards  Age  Education  Own Student Married Region  \
# 0   14.891   3606     283      2   34         11   No      No     Yes  South
# 1  106.025   6645     483      3   82         15  Yes     Yes     Yes   West
# 2  104.593   7075     514      4   71         11   No      No      No   West
#
#    Balance
# 0      333
# 1      903
# 2      580

# %%
#Q4-Get descriptive statistics of data
df.describe()
# Out:
#            Income         Limit      Rating       Cards         Age  \
# count  400.000000    400.000000  400.000000  400.000000  400.000000
# mean    45.218885   4735.600000  354.940000    2.957500   55.667500
# std     35.244273   2308.198848  154.724143    1.371275   17.249807
# min     10.354000    855.000000   93.000000    1.000000   23.000000
# 25%     21.007250   3088.000000  247.250000    2.000000   41.750000
# 50%     33.115500   4622.500000  344.000000    3.000000   56.000000
# 75%     57.470750   5872.750000  437.250000    4.000000   70.000000
# max    186.634000  13913.000000  982.000000    9.000000   98.000000
#
#         Education      Balance
# count  400.000000   400.000000
# mean    13.450000   520.015000
# std      3.125207   459.758877
# min      5.000000     0.000000
# 25%     11.000000    68.750000
# 50%     14.000000   459.500000
# 75%     16.000000   863.000000
# max     20.000000  1999.000000

# %%
#Q5-Use seasoborns heat map to generate following heatmap
# annot = True to print the correlation inside the square
plt.figure(figsize=(12, 10))

numeric_df = df.select_dtypes(include=np.number)

correlation_matrix = numeric_df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
#Q6-Plot the density distribution of Balance
sns.kdeplot(df['Balance'])
plt.xlabel('Balance')
plt.ylabel('Density')
plt.title('Density Distribution of Balance')
plt.show()

# %%
#Q7-Count the frequency values of each Region
region_frequencies = df['Region'].value_counts()
print(region_frequencies)
# Out:
# Region
# South    199
# West     102
# East      99
# Name: count, dtype: int64

# %%
#Q8-List Percentage of  the Married people
percentage_married = (df['Married'].value_counts(normalize=True) * 100)['Yes']
print(f"Percentage of Married People: {percentage_married:.2f}%")
# Out:
# Percentage of Married People: 61.25%

# %%
#Q9-Create histogram of Balance
plt.hist(df['Balance'], bins=10, edgecolor='k')
plt.xlabel('Balance')
plt.ylabel('Frequency')
plt.title('Histogram of Balance')
plt.show()

# %%
#Q10-Get the frequency distribution of Region using bar graph
plt.figure(figsize=(8, 6))
region_counts = df['Region'].value_counts()
plt.bar(region_counts.index, region_counts.values)
# Out:
# <BarContainer object of 3 artists>

# %%
#Q11-Get the mean income  of married people?
plt.figure(figsize=(8, 6))
married_df = df[df['Married'] == 'Yes']
mean_income_married = married_df['Income'].mean()
print(f"Mean Income of Married People: {mean_income_married:.2f}")
# Out:
# Mean Income of Married People: 46.22

# %%
#Q12-Get the scatter plot of Income and Limit
df.plot(x='Income', y='Limit', kind='scatter')
# Out:
# <Axes: xlabel='Income', ylabel='Limit'>

# %%
#Q13-Create new column named IncomebyLimit by dividing Income to Limit.
plt.figure(figsize=(8, 6))
df['IncomebyLimit'] = df['Income'] / df['Limit']
print(df['IncomebyLimit'])
# Out:
# 0      0.004130
# 1      0.015956
# 2      0.014783
# 3      0.015670
# 4      0.011411
#          ...
# 395    0.002950
# 396    0.003482
# 397    0.013875
# 398    0.014942
# 399    0.003385
# Name: IncomebyLimit, Length: 400, dtype: float64

# %%
# Q14-Create the pair plot using Seaborn library's pairplot
plt.figure(figsize=(10, 8))
sns.pairplot(df)

# %%
#Q15- drop new column named IncomebyLimit from dataframe
df = df.drop('IncomebyLimit', axis=1)

# %%
#show new column
df.head(-5)
# Out:
#       Income  Limit  Rating  Cards  Age  Education  Own Student Married  \
# 0     14.891   3606     283      2   34         11   No      No     Yes
# 1    106.025   6645     483      3   82         15  Yes     Yes     Yes
# 2    104.593   7075     514      4   71         11   No      No      No
# 3    148.924   9504     681      3   36         11  Yes      No      No
# 4     55.882   4897     357      2   68         16   No      No     Yes
# ..       ...    ...     ...    ...  ...        ...  ...     ...     ...
# 390  135.118  10578     747      3   81         15  Yes      No     Yes
# 391   73.327   6555     472      2   43         15  Yes      No      No
# 392   25.974   2308     196      2   24         10   No      No      No
# 393   17.316   1335     138      2   65         13   No      No      No
# 394   49.794   5758     410      4   40          8   No      No      No
#
#     Region  Balance
# 0    South      333
# 1     West      903
# 2     West      580
# 3     West      964
# 4    South      331
# ..     ...      ...
# 390   West     1393
# 391  South      721
# 392   West        0
# 393   East        0
# 394  South      734
#
# [395 rows x 11 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Income'].plot(kind='hist', bins=20, title='Income')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Limit'].plot(kind='hist', bins=20, title='Limit')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Rating'].plot(kind='hist', bins=20, title='Rating')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['Cards'].plot(kind='hist', bins=20, title='Cards')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('Own').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_5.groupby('Student').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_6.groupby('Married').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_7.groupby('Region').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='Income', y='Limit', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9.plot(kind='scatter', x='Limit', y='Rating', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10.plot(kind='scatter', x='Rating', y='Cards', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11.plot(kind='scatter', x='Cards', y='Age', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['Income'].plot(kind='line', figsize=(8, 4), title='Income')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['Limit'].plot(kind='line', figsize=(8, 4), title='Limit')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['Rating'].plot(kind='line', figsize=(8, 4), title='Rating')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['Cards'].plot(kind='line', figsize=(8, 4), title='Cards')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Student'].value_counts()
#     for x_label, grp in _df_16.groupby('Own')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Own')
# _ = plt.ylabel('Student')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Married'].value_counts()
#     for x_label, grp in _df_17.groupby('Student')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Student')
# _ = plt.ylabel('Married')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Region'].value_counts()
#     for x_label, grp in _df_18.groupby('Married')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Married')
# _ = plt.ylabel('Region')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_19['Own'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_19, x='Income', y='Own', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_20['Student'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_20, x='Income', y='Student', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_21['Married'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_21, x='Income', y='Married', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_22['Region'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_22, x='Income', y='Region', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
